# %%
import requests
aqi_url = "https://data.epa.gov.tw/api/v1/aqx_p_432?offset=0&limit=80&api_key=55947996-ddaf-4625-bc10-d7801140485e" 
# 環保署環境資料開放平臺 試行版 https://data.epa.gov.tw/
# API 金鑰免費申請 ～
response = requests.get(aqi_url)
aqi = response.json()['records']
# dict >> list
print(response.status_code)

### 200  正常回傳
### 404 回傳錯誤
print(type(response))
print(type(aqi))

for wa in aqi :
    print(wa["County"], wa["SiteName"], wa["PM2.5"])
    
    
with open("data_pm25.txt", "w", encoding="utf-8") as file:
     for list in aqi:
        file.write(f'{list["County"]} {list["SiteName"]} {list["PM2.5"]}\n')
# Out:
# 200
# <class 'requests.models.Response'>
# <class 'list'>
# 基隆市 基隆 11
# 新北市 汐止 6
# 新北市 萬里 11
# 新北市 新店 8
# 新北市 土城 8
# 新北市 板橋 5
# 新北市 新莊 7
# 新北市 菜寮 6
# 新北市 林口 8
# 新北市 淡水 6
# 臺北市 士林 6
# 臺北市 中山 11
# 臺北市 萬華 6
# 臺北市 古亭 7
# 臺北市 松山 12
# 臺北市 大同 4
# 桃園市 桃園 5
# 桃園市 大園 6
# 桃園市 觀音 8
# 桃園市 平鎮 5
# 桃園市 龍潭 3
# 新竹縣 湖口 6
# 新竹縣 竹東 2
# 新竹市 新竹 2
# 苗栗縣 頭份 8
# 苗栗縣 苗栗 11
# 苗栗縣 三義 13
# 臺中市 豐原 18
# 臺中市 沙鹿 10
# 臺中市 大里 22
# 臺中市 忠明 17
# 臺中市 西屯 14
# 彰化縣 彰化 17
# 彰化縣 線西 10
# 彰化縣 二林 15
# 南投縣 南投 29
# 雲林縣 斗六 27
# 雲林縣 崙背 14
# 嘉義縣 新港 15
# 嘉義縣 朴子 21
# 雲林縣 臺西 9
# 嘉義市 嘉義 30
# 臺南市 新營 21
# 臺南市 善化 20
# 臺南市 安南 21
# 臺南市 臺南 20
# 高雄市 美濃 14
# 高雄市 橋頭 26
# 高雄市 仁武 17
# 高雄市 鳳山 26
# 高雄市 大寮 20
# 高雄市 林園 13
# 高雄市 楠梓 19
# 高雄市 左營 15
# 高雄市 前金 17
# 高雄市 前鎮 21
# 高雄市 小港 30
# 屏東縣 屏東 23
# 屏東縣 潮州 24
# 屏東縣 恆春 5
# 臺東縣 臺東 6
# 花蓮縣 花蓮 7
# 臺北市 陽明 3
# 宜蘭縣 宜蘭 9
# 宜蘭縣 冬山 5
# 新北市 三重 10
# 桃園市 中壢 12
# 南投縣 竹山 40
# 新北市 永和 7
# 高雄市 復興 22
# 南投縣 埔里 34
# 連江縣 馬祖 11
# 金門縣 金門 8
# 澎湖縣 馬公 11
# 臺東縣 關山 3
# 雲林縣 麥寮 11
# 新北市 富貴角 9
# 彰化縣 彰化(員林) 18
# 彰化縣 彰化(大城) 10
# 臺南市 臺南(麻豆) 19
